# %% [markdown]
# <a href="https://colab.research.google.com/github/dembor5317/ABCD-A/blob/20250310/%ED%8C%8C%EC%9D%B4%EC%8D%AC_%EA%B8%B0%EC%B4%881_%EB%B3%80%EC%88%9820250310.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
watch=100000
print(watch)
# Out:
# 100000

# %%
a='pig'
b='dad'

print(a)
print(b)
print(a+b)
print(a+''+b)
# Out:
# pig
# dad
# pigdad
# pigdad

# %%
aa=1
bb=100
aa,bb=bb,aa
print(aa)
print(bb)
# Out:
# 100
# 1

# %%
a1=[10,20,30]
b1=a1
a1[0]=200
print(b1)
# Out:
# [200, 20, 30]

# %%
print("Hello world")
print('Hello world')
print(1)
print("1")
# Out:
# Hello world
# Hello world
# 1
# 1

# %%
c=1
print("c="+str(c))
print("c",c)
print("c={}",format(c))
# Out:
# c=1
# c 1
# c={} 1

# %%
a=[10,20,30]
b=1
c=2
print(a)
print("a={}".format(a))
print("b={}".format(b))
print("a={},b={},c={}".format(a,b,c))
# Out:
# [10, 20, 30]
# a=[10, 20, 30]
# b=1
# a=[10, 20, 30],b=1,c=2
