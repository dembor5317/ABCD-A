# %% [markdown]
# <a href="https://colab.research.google.com/github/dembor5317/ABCD-A/blob/20250321/python%EA%B8%B0%EC%B4%883.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 4/3
# Out:
# 1.3333333333333333

# %%
1/2
# Out:
# 0.5

# %%
4/2
# Out:
# 2.0

# %%
7/3
# Out:
# 2.3333333333333335

# %%
7%3
# Out:
# 1

# %%
2**10
# Out:
# 1024

# %%
int(5/2)
# Out:
# 2

# %%
5//2
# Out:
# 2

# %%
a=1024
print(a)
# Out:
# 1024

# %%
divmod(5,2)
# Out:
# (2, 1)

# %%
quotient,remainder=divmod(5,2)

# %%
print (quotient,remainder)
# Out:
# 2 1

# %%
a=11+2
b=12-2
c=13*2
d = 14/2
e = 15**2
f = 16//2
g = 17%3
print(a,b,c,d,e,f,g)
# Out:
# 13 10 26 7.0 225 8 2

# %%
i=3
i += 3
print(i)
i -= 3
print(i)
i *=2
print(i)
i /=2
print(int (i))
i = 3
i %=2
print(i)
# Out:
# 4
# 1
# 2
# 1
# 1

# %%
a = 10
b = 3
print("10 == 3 =>", a==b)
print("10 != 3 =>", a!=b)
print("10 > 3 =>", a>b)
print("10 > =3 =>", a>=b)
print("10 <= 3 =>", a <=b)
print()
# Out:
# 10 == 3 => False
# 10 != 3 => True
# 10 > 3 => True
# 10 > =3 => True
# 10 <= 3 => False

# %%
bin(13)
# Out:
# '0b1101'

# %%
0b1101
# Out:
# 13

# %%
int('1101',2)
# Out:
# 13

# %%
bin(0b1101&0b1101)
# Out:
# '0b1101'

# %%
13&9
# Out:
# 9

# %%
bin(0b1101&0b1101)
# Out:
# '0b1101'

# %%
bin(0b1101^0b1101)
# Out:
# '0b0'

# %%
bin(~0b1101)
# Out:
# '-0b1110'
