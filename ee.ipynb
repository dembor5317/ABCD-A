# %%
# YOLOv8 설치
# !pip install ultralytics

# %%
#압축 해제
import zipfile

with zipfile.ZipFile('final_exam.v3i.yolov8.zip') as zip_ref:
    zip_ref.extractall('dataset')

# %%
#학습
from ultralytics import YOLO
model = YOLO('yolov8n-seg.pt')  # 또는 yolov8s-seg.pt 등
model.train(
    data='dataset/data.yaml', #yaml 수정
    epochs=1000, #횟수
    imgsz=640,
    task='segment',
    workers=0,
    patience=0
)
# Out:
# Ultralytics 8.3.146  Python-3.10.16 torch-2.1.2+cu118 CUDA:0 (NVIDIA GeForce RTX 3070, 8192MiB)
# ...

# %%
from ultralytics import YOLO

# 학습된 YOLOv8 세그멘테이션 모델 불러오기
model = YOLO('runs/segment/train2/weights/best.pt')

# 원본 이미지 폴더에 대해 추론 실행
results = model('dataset/train/images', save=True, task='segment')
# Out:
# image 1/240 C:\Users\halla\Desktop\finalexam\dataset\train\images\512_ND_0000_CF_001_jpg.rf.3696396b475aaf4499b548364a974a2b.jpg: 640x640 1 Red-light, 3 Traffic-lights, 33.7ms
# image 2/240 C:\Users\halla\Desktop\finalexam\dataset\train\images\512_ND_0000_CF_002_jpg.rf.e16d982b5d088f5bfb42f4a60c2f0858.jpg: 640x640 1 Red-light, 3 Traffic-lights, 68.9ms
# image 3/240 C:\Users\halla\Desktop\finalexam\dataset\train\images\512_ND_0000_CF_004_jpg.rf.776d2f97166e56c74a6d37327ff6d739.jpg: 640x640 1 Red-light, 3 Traffic-lights, 49.8ms
# image 4/240 C:\Users\halla\Desktop\finalexam\dataset\train\images\512_ND_0000_CF_005_jpg.rf.2ea962b03c5096f2ef4ad20411b4f5bb.jpg: 640x640 1 Red-light, 3 Traffic-lights, 55.0ms
# image 5/240 C:\Users\halla\Desktop\finalexam\dataset\train\images\512_ND_0000_CF_006_jpg.rf.4690f2b069920fdec4eb53dedcb9e721.jpg: 640x640 2 Red-lights, 2 Traffic-lights, 13.2ms
# ...

# %%
import cv2
import os
from glob import glob

img_folder = 'runs/segment/predict' #상대 주소로 runs 뒤부터 바꾸고
output_video = 'segmentation_result2.mp4'

# 이미지 목록
img_files = sorted(glob(os.path.join(img_folder, '*.jpg')) + glob(os.path.join(img_folder, '*.png')))
if not img_files:
    print("❌ 결과 이미지가 없습니다.")
    exit()

# 비디오 설정
frame = cv2.imread(img_files[0])
height, width, _ = frame.shape
video = cv2.VideoWriter(output_video, cv2.VideoWriter_fourcc(*'mp4v'), 5, (width, height))

for img in img_files:
    video.write(cv2.imread(img))

video.release()
print(f"✅ 비디오 저장 완료: {output_video}")
# Out:
# ✅ 비디오 저장 완료: segmentation_result2.mp4

# %%
from ultralytics import YOLO
import cv2

# 모델 경로 (절대 경로)
model_path = 'C:/Users/halla/Desktop/finalexam/runs/segment/train2/weights/best.pt' #이거 경로 찾아서 이거 역슬레시 안먹음 역슬레시면 슬레시로 체체
model = YOLO(model_path, task='segment')

# 비디오 경로 (같은 폴더에 있다면 아래처럼 절대 경로로)
video_path = 'C:/Users/halla/Desktop/finalexam/KakaoTalk_20250605_221751277.mp4' #이거 경로 찾아서 체체
cap = cv2.VideoCapture(video_path)

# 비디오 저장 설정
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter('output_video.mp4', fourcc, 30.0, (int(cap.get(3)), int(cap.get(4))))

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    results = model(frame)
    annotated_frame = results[0].plot()

    cv2.imshow('Segmented Frame', annotated_frame)  # Colab 아님 → cv2.imshow 사용
    out.write(annotated_frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 1 Red-light, 41.3ms
# Speed: 2.1ms preprocess, 41.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Red-light, 45.1ms
# Speed: 3.1ms preprocess, 45.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Red-light, 63.8ms
# Speed: 1.7ms preprocess, 63.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Red-light, 9.7ms
# Speed: 1.2ms preprocess, 9.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Red-light, 10.2ms
# Speed: 1.1ms preprocess, 10.2ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Red-light, 9.4ms
# Speed: 1.1ms preprocess, 9.4ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Red-light, 8.8ms
# Speed: 1.1ms preprocess, 8.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Red-light, 8.9ms
# ...
