# %% [markdown]
# <a href="https://colab.research.google.com/github/dembor5317/ABCD-A/blob/20250410/%EB%AC%BC%EB%A6%AC_3%EC%9E%A5_%EB%B9%84%EC%8A%A4%EB%93%AC%EC%9D%B4_%EB%8D%98%EC%A7%84_%EA%B3%B5%EC%9D%98_%EC%9A%B4%EB%8F%99_%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%98%EB%B0%8D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

# 입력
v0 = float(input("초기 속도 v0 (m/s): "))
angle_deg = float(input("발사 각도 (도): "))
h = float(input("초기 높이 h (m): "))

g = 9.8
angle_rad = math.radians(angle_deg)

# 속도 성분
v0x = v0 * math.cos(angle_rad)
v0y = v0 * math.sin(angle_rad)

# (1) 시간 계산 (이차방정식: 0 = h + v0y*t - 0.5*g*t^2)
a = -0.5 * g
b = v0y
c = h

discriminant = b**2 - 4*a*c
if discriminant < 0:
    print("해가 존재하지 않습니다.")
    exit()
1
t1 = (-b + math.sqrt(discriminant)) / (2 * a)
t2 = (-b - math.sqrt(discriminant)) / (2 * a)
t = max(t1, t2)

# (2) 수평 거리
x = v0x * t

# (3) 충돌 시 속도 성분
vx = v0x
vy = v0y - g * t

# (4) 속도 크기
v = math.sqrt(vx**2 + vy**2)

# (5) 속도 방향
theta = math.degrees(math.atan2(vy, vx))

# 출력
print(f"\n① 충돌까지 시간: {t:.2f} 초")
print(f"② 수평 거리: {x:.2f} m")
print(f"③ 충돌 순간 속도 성분 - Vx: {vx:.2f} m/s, Vy: {vy:.2f} m/s")
print(f"④ 충돌 순간 속도 크기: {v:.2f} m/s")
print(f"⑤ 속도 방향 각도 (수평 기준): {theta:.2f} 도")
# Out:
# 초기 속도 v0 (m/s): 10
# 발사 각도 (도): 37
# 초기 높이 h (m): 140
#
# ① 충돌까지 시간: 5.99 초
# ② 수평 거리: 47.87 m
# ③ 충돌 순간 속도 성분 - Vx: 7.99 m/s, Vy: -52.73 m/s
# ④ 충돌 순간 속도 크기: 53.33 m/s
# ⑤ 속도 방향 각도 (수평 기준): -81.39 도
